# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"D:\PythonProjects\StudentStressAnalisys\Student Stress Factors.csv")
df.head()
# Out:
#              Timestamp  Kindly Rate your Sleep Quality 😴  \
# 0  27/10/2023 21:54:15                                 3
# 1  28/10/2023 12:24:40                                 4
# 2  28/10/2023 12:24:51                                 2
# 3  28/10/2023 12:26:11                                 3
# 4  28/10/2023 12:26:45                                 2
#
#    How many times a week do you suffer headaches 🤕?  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 2
# 4                                                 3
#
#    How would you rate you academic performance 👩‍🎓?  \
# 0                                                 3
# 1                                                 2
# 2                                                 2
# 3                                                 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 7 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Timestamp                                                         53 non-null     object
#  1   Kindly Rate your Sleep Quality 😴                                  53 non-null     int64
#  2   How many times a week do you suffer headaches 🤕?                  53 non-null     int64
#  3   How would you rate you academic performance 👩‍🎓?                  53 non-null     int64
#  4   how would you rate your study load?                               53 non-null     int64
#  5   How many times a week you practice extracurricular activities 🎾?  53 non-null     int64
#  6   How would you rate your stress levels?                            53 non-null     int64
# dtypes: int64(6), object(1)
# ...

# %% [markdown]
# ### Sleep Quality vs. Stress Levels:

# %%
sleep_quality = df['Kindly Rate your Sleep Quality 😴']
stress_levels = df['How would you rate your stress levels?']

# Calculate the correlation between Sleep Quality and Stress Levels
correlation = sleep_quality.corr(stress_levels)

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(sleep_quality, stress_levels, color='blue', alpha=0.6)
plt.title('Sleep Quality vs. Stress Levels')
plt.xlabel('Sleep Quality')
plt.ylabel('Stress Levels')
plt.grid(True)

# Display the correlation coefficient on the plot
plt.text(1, 5, f'Correlation: {correlation:.2f}', fontsize=12, color='red')

# Show the plot
plt.show()

# %% [markdown]
# ### Headache Frequency:

# %%
# Select the column for headache frequency
headache_frequency = df['How many times a week do you suffer headaches 🤕?']

# Calculate the average headache frequency
average_frequency = headache_frequency.mean()

# Create a bar chart to visualize the distribution
plt.figure(figsize=(8, 6))
plt.hist(headache_frequency, bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Headache Frequency')
plt.xlabel('Headache Frequency (times per week)')
plt.ylabel('Count')

# Display the average frequency on the chart
plt.axvline(average_frequency, color='red', linestyle='dashed', linewidth=2, label=f'Average Frequency: {average_frequency:.2f}')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Academic Performance vs. Study Load:

# %%
# Select the columns for analysis
academic_performance = df['How would you rate you academic performance 👩‍🎓?']
study_load = df['how would you rate your study load?']

# Calculate the correlation between Academic Performance and Study Load
correlation = academic_performance.corr(study_load)

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(academic_performance, study_load, color='green', alpha=0.6)
plt.title('Academic Performance vs. Study Load')
plt.xlabel('Academic Performance')
plt.ylabel('Study Load')
plt.grid(True)

# Display the correlation coefficient on the plot
plt.text(2, 5, f'Correlation: {correlation:.2f}', fontsize=12, color='red')

# Show the plot
plt.show()

# %% [markdown]
# ### Extracurricular Activities:

# %%
# Select the column for extracurricular activity frequency
activity_frequency = df['How many times a week you practice extracurricular activities 🎾?']

# Calculate the average activity frequency
average_frequency = activity_frequency.mean()

# Create a bar chart to visualize the distribution
plt.figure(figsize=(8, 6))
plt.hist(activity_frequency, bins=10, color='lightcoral', edgecolor='black')
plt.title('Distribution of Extracurricular Activity Frequency')
plt.xlabel('Activity Frequency (times per week)')
plt.ylabel('Count')

# Display the average frequency on the chart
plt.axvline(average_frequency, color='blue', linestyle='dashed', linewidth=2, label=f'Average Frequency: {average_frequency:.2f}')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Stress Levels Distribution:

# %%
# Select the column for stress levels
stress_levels = df['How would you rate your stress levels?']

# Create a histogram to visualize the distribution
plt.figure(figsize=(8, 6))
plt.hist(stress_levels, bins=5, color='salmon', edgecolor='black')
plt.title('Distribution of Stress Levels')
plt.xlabel('Stress Levels')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ### Time-based Analysis:

# %%
# Convert the "Timestamp" column to a datetime object
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
# Out:
# C:\Users\Макар\AppData\Local\Temp\ipykernel_20516\2294468860.py:2: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['Kindly Rate your Sleep Quality 😴'], label='Sleep Quality', marker='o')
plt.xlabel('Timestamp')
plt.ylabel('Sleep Quality')
plt.title('Sleep Quality Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['How many times a week do you suffer headaches 🤕?'], label='Headache Frequency', marker='o', color='orange')
plt.xlabel('Timestamp')
plt.ylabel('Headache Frequency')
plt.title('Headache Frequency Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Frequency of Responses:

# %%
# Convert the "Timestamp" column to a datetime object
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Count the number of responses for each unique timestamp
response_counts = df['Timestamp'].value_counts().sort_index()

# Create a line plot to visualize the response frequency over time
plt.figure(figsize=(12, 6))
response_counts.plot(marker='o', color='skyblue')
plt.title('Frequency of Responses Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Number of Responses')
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible: 'bool | None' = None, which: "Literal['major', 'minor', 'both']" = 'major', axis: "Literal['both', 'x', 'y']" = 'both', **kwargs) -> 'None'>

# %% [markdown]
# ### Summary Statistics:

# %%
# Select the numeric columns for which you want to calculate summary statistics
numeric_columns = ['Kindly Rate your Sleep Quality 😴', 'How many times a week do you suffer headaches 🤕?',
                   'How would you rate you academic performance 👩‍🎓?', 'how would you rate your study load?',
                   'How many times a week you practice extracurricular activities 🎾?',
                   'How would you rate your stress levels?']

# Calculate and display summary statistics
summary_statistics = df[numeric_columns].describe()

# Print the summary statistics
print(summary_statistics)
# Out:
#        Kindly Rate your Sleep Quality 😴  \
# count                         53.000000
# mean                           3.150943
# std                            1.199298
# min                            1.000000
# 25%                            2.000000
# 50%                            3.000000
# 75%                            4.000000
# max                            5.000000
#
#        How many times a week do you suffer headaches 🤕?  \
# count                                         53.000000
# mean                                           1.981132
# std                                            1.263246
# min                                            1.000000
# 25%                                            1.000000
# 50%                                            1.000000
# 75%                                            3.000000
# max                                            5.000000
#
#        How would you rate you academic performance 👩‍🎓?  \
# ...

# %%
df.describe()
# Out:
#                            Timestamp  Kindly Rate your Sleep Quality 😴  \
# count                             53                         53.000000
# mean   2023-10-28 17:40:50.735848960                          3.150943
# min              2023-10-27 21:54:15                          1.000000
# 25%              2023-10-28 12:40:50                          2.000000
# 50%              2023-10-28 13:44:07                          3.000000
# 75%              2023-10-28 16:34:16                          4.000000
# max              2023-10-31 20:49:11                          5.000000
# std                              NaN                          1.199298
#
#        How many times a week do you suffer headaches 🤕?  \
# count                                         53.000000
# mean                                           1.981132
# min                                            1.000000
# 25%                                            1.000000
# ...

# %% [markdown]
# ### Comparative Analysis:

# %%
# Select the columns for analysis
academic_performance = df['How would you rate you academic performance 👩‍🎓?']
extracurricular_activities = df['How many times a week you practice extracurricular activities 🎾?']

# Create a scatter plot to compare academic performance and extracurricular activities
plt.figure(figsize=(8, 6))
plt.scatter(academic_performance, extracurricular_activities, color='purple', alpha=0.6)
plt.title('Academic Performance vs. Extracurricular Activities')
plt.xlabel('Academic Performance')
plt.ylabel('Extracurricular Activities')
plt.grid(True)

# Show the plot
plt.show()

# %%
# Select the columns for analysis
sleep_quality = df['Kindly Rate your Sleep Quality 😴']
stress_levels = df['How would you rate your stress levels?']

# Create a scatter plot to compare sleep quality and stress levels
plt.figure(figsize=(8, 6))
plt.scatter(sleep_quality, stress_levels, color='orange', alpha=0.6)
plt.title('Sleep Quality vs. Stress Levels')
plt.xlabel('Sleep Quality')
plt.ylabel('Stress Levels')
plt.grid(True)

# Show the plot
plt.show()
